# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas.tseries.offsets import Nano

# %%
# Load the data from the CSV file
df = pd.read_csv('results/creation_time_0.csv')

bin_size = 1000
bin_edges = np.arange(0, df['i'].max() + bin_size, bin_size)

df['bin'] = pd.cut(df['i'], bins=bin_edges)
df_grouped = df.groupby('bin')['time_taken'].mean()

colors = ['blue' if i%2 == 0 else 'orange' for i in range(len(df_grouped))]

plt.bar(range(len(df_grouped)), df_grouped, align='edge', width=0.8, color=colors)

plt.xlabel('Number of Events (in thousands)')
plt.ylabel('Average Time Taken')
plt.title('Average Time Taken for Each Thousand Events')

plt.ylim(df_grouped.min() - 0.001, df_grouped.max() + 0.001)

plt.show()
